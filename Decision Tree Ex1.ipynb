# %%
from sklearn import tree
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
from sklearn.datasets import load_iris
data = load_iris()
data.target[[10, 25, 50]]

list(data.target_names)
iris = datasets.load_iris()
clf = tree.DecisionTreeClassifier() 
clf.max_depth = 5 

clf.criterion = 'entropy'
clf = clf.fit(iris.data, iris.target)
print("Decision Tree: ")

accuracy = cross_val_score(clf, iris.data, iris.target, scoring='accuracy', cv=10)
print("Average Accuracy of DT with depth ", clf.max_depth, " is: ",
round(accuracy.mean(),3))
# Out:
# Decision Tree:
# Average Accuracy of DT with depth  5  is:  0.953

# %%
precision = cross_val_score(clf, iris.data, iris.target, scoring='precision_weighted',
cv=10) 
X = iris.data
plt.plot(X, [x * x for x in X])
plt.xlabel("Tree Depth")
plt.ylabel("Tree Number")
plt.show()

# %%
print(type(iris.data))
print(type(iris.target))
print(iris.data.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (150, 4)

# %%
X = iris.data # feature matrix

y = iris.target # response vector

# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=100,random_state=0)

# scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# prediction
y_pred=clf.predict(x_test)

# evaluation
# --- accuracy
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print(f"accuracy: {acc}")

# --- confusion matrix
# --- ---- ordinary
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# accuracy: 0.31
# Confusion Matrix:
# [[31  0]
#  [33  0]]

# %%
# --- recall
from sklearn.metrics import recall_score
recall = recall_score(y_test,y_pred,average='weighted')
print(f"Recall: {recall}")
# Out:
# Recall: 0.31

# %%
# f1 score
from sklearn.metrics import  f1_score
f1 = f1_score(y_test,y_pred,average='weighted')
print(f"f1: {f1}")
# Out:
# f1: 0.14671755725190838

# %%
from sklearn.datasets import load_wine
data = load_wine()
data.target[[10, 80, 140]]

list(data.target_names)
wine = datasets.load_wine() 

X = wine.data
plt.plot(X, [x * x for x in X])
plt.xlabel("Tree Depth")
plt.ylabel("Tree Number")
plt.show()

# %%
clf2 = tree.DecisionTreeClassifier() 
clf2.max_depth = 5 
clf2.criterion = 'entropy' 
clf2 = clf2.fit(wine.data, wine.target) 
 
print("Decision Tree: ") 
accuracy = cross_val_score(clf2, wine.data, wine.target, scoring='accuracy', cv=10) 
 
print("Average Accuracy of  DT with depth ", clf2.max_depth, " is: ", round(accuracy.mean(),3)) 
 
#mylist.append(accuracy.mean())  loop, can be used to plot later… 
 
precision = cross_val_score(clf2, wine.data, wine.target, scoring='precision_weighted', cv=10)  
print("Average precision_weighted of  DT with depth ", clf2.max_depth, " is: ", round(precision.mean(),3)) 

from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
plt.plot(X, [x * x for x in X])
plt.xlabel("Tree Depth")
plt.ylabel("Tree Number")
plt.show()
# Out:
# Decision Tree:
# Average Accuracy of  DT with depth  5  is:  0.904
# Average precision_weighted of  DT with depth  5  is:  0.929

# %%
clf = tree.DecisionTreeClassifier() 
clf.max_depth = 5 
clf.criterion = 'entropy' 
clf = clf.fit(digits.data, digits.target) 
 
print("Decision Tree: ") 
accuracy = cross_val_score(clf, digits.data, digits.target, scoring='accuracy', cv=10) 
 
print("Average Accuracy of  DT with depth ", clf.max_depth, " is: ", round(accuracy.mean(),3)) 
 
#mylist.append(accuracy.mean())  loop, can be used to plot later… 
 
precision = cross_val_score(clf, digits.data, digits.target, scoring='precision_weighted', cv=10)  
print("Average precision_weighted of  DT with depth ", clf.max_depth, " is: ", round(precision.mean(),3))
# Out:
# Decision Tree:
# Average Accuracy of  DT with depth  5  is:  0.736
# Average precision_weighted of  DT with depth  5  is:  0.772
